# %% [markdown]
# # CUSP London Data Dive 2023

# %% [markdown]
# ## Challenge we choose / Research Question:
# 1.  Do common mental health problems (depression and anxiety) cluster in particular geographical areas across the country (UK)?
# 2.  **Are serious mental health problems (psychosis- schizophrenia and bipolar affective disorders) more prevalent in urban built areas?**
# 3.  What physical features of the built environment (green space, air pollution levels, street intersections (‘neighbourhood walkability’), any others- this list is not exhaustive) are associated with mental health conditions (common mental health conditions and/ or serious mental health conditions)?
# 4.  **What social features of the environment (population density, social disorganisation, any others- list is not exhaustive) are associated with mental health conditions (common mental health conditions and/ or serious mental health conditions)?**
# 5.  Do mental health issues correlate with known physical health issues?
#
# ## Data Source:
#
# 1. [Mental Health Index 2011](https://pldr.org/dataset/2noyv/small-area-mental-health-index-samhi)
# 2. [Population Density Census 2011](https://www.nomisweb.co.uk/census/2011/qs102ew)
# 3. [Deprivation 2010](https://www.gov.uk/government/statistics/english-indices-of-deprivation-2010)
# 4. [Statistical Boundary london 2011](https://data.london.gov.uk/dataset/statistical-gis-boundary-files-london)
# 5. Household Composition England and Wales 2011(https://www.nomisweb.co.uk/census/2011/ks105ew)
#
# ## Assumption:
#
#
# ## Limitation:

# %% [markdown]
# # Import Modules

# %%
# Import required libraries

# Import visualisation modules
import matplotlib as mpl 
# %matplotlib inline 
import matplotlib.pyplot as plt 

#Import modules
import osmnx as ox
import pandas as pd
import geopandas as gpd
import numpy as np
import contextily as ctx

#Import datareading modules
import fiona
import urllib
from urllib.request import urlopen
import csv
import os
import tempfile
import shutil
from pathlib import Path

import warnings 
warnings.simplefilter(action='ignore')
ox.__version__
# Out:
# '1.2.2'

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Population Density

# %%
# Read the file from github repo URL
url = "https://raw.githubusercontent.com/ListianingrumR/cusp_london_data_dive_2023/main/data/samhi_21_01_v4.00_2011_2019_LSOA.csv"
pd_df= pd.read_csv(url)

pd_df.head(5)
# Out:
#       lsoa11  samhi_index.2011  samhi_dec.2011  samhi_index.2012  \
# 0  E01000001         -1.733070               1         -1.665014
# 1  E01000002         -1.704465               1         -1.719869
# 2  E01000003         -0.920870               4         -0.686420
# 3  E01000005         -1.218240               2         -1.262427
# 4  E01000006         -1.892813               1         -1.837497
#
#    samhi_dec.2012  samhi_index.2013  samhi_dec.2013  samhi_index.2014  \
# 0               1         -1.729767               1         -1.460658
# 1               1         -1.783252               1         -1.749144
# 2               5         -0.357678               7         -0.571222
# 3               2         -0.951074               3         -0.720833
# 4               1         -1.784586               1         -1.724196
#
#    samhi_dec.2014  samhi_index.2015  samhi_dec.2015  samhi_index.2016  \
# 0               1         -1.428309               1         -1.507283
# 1               1         -1.531450               1         -1.456034
# 2               4         -0.567158               4         -0.574356
# 3               4         -1.016268               2         -0.679462
# 4               1         -1.630328               1         -1.537457
#
#    samhi_dec.2016  samhi_index.2017  samhi_dec.2017  samhi_index.2018  \
# 0               1         -1.326553               1         -1.371607
# 1               1         -1.383528               1         -1.242643
# 2               3         -0.504734               2         -0.501422
# 3               2         -0.805106               1         -0.695488
# 4               1         -1.352359               1         -1.452954
#
#    samhi_dec.2018  samhi_index.2019  samhi_dec.2019
# 0               1         -1.183468               1
# 1               1         -1.189840               1
# 2               2         -0.580351               1
# 3               1         -0.897460               1
# 4               1         -1.237533               1

# %%
pd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32844 entries, 0 to 32843
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   lsoa11            32844 non-null  object
#  1   samhi_index.2011  32844 non-null  float64
#  2   samhi_dec.2011    32844 non-null  int64
#  3   samhi_index.2012  32844 non-null  float64
#  4   samhi_dec.2012    32844 non-null  int64
#  5   samhi_index.2013  32844 non-null  float64
#  6   samhi_dec.2013    32844 non-null  int64
#  7   samhi_index.2014  32844 non-null  float64
#  8   samhi_dec.2014    32844 non-null  int64
#  9   samhi_index.2015  32844 non-null  float64
#  10  samhi_dec.2015    32844 non-null  int64
#  11  samhi_index.2016  32844 non-null  float64
#  12  samhi_dec.2016    32844 non-null  int64
#  13  samhi_index.2017  32844 non-null  float64
#  14  samhi_dec.2017    32844 non-null  int64
#  15  samhi_index.2018  32844 non-null  float64
#  16  samhi_dec.2018    32844 non-null  int64
#  17  samhi_index.2019  32844 non-null  float64
#  18  samhi_dec.2019    32844 non-null  int64
# dtypes: float64(9), int64(9), object(1)
# memory usage: 4.8+ MB

# %% [markdown]
# ## Deprivation

# %%
# Read the file from github repo URL
url = "https://raw.githubusercontent.com/ListianingrumR/cusp_london_data_dive_2023/main/data/CLSHHD_LSOADZ_England_Scotland_Wales_Descriptions.csv"
dep_df= pd.read_csv(url)

dep_df.head(5)
# Out:
#     GEO_CODE                  GEO_LABEL  \
# 0  E01000001        City of London 001A
# 1  E01000002        City of London 001B
# 2  E01000003        City of London 001C
# 3  E01000005        City of London 001E
# 4  E01000006  Barking and Dagenham 016A
#
#                                   GEO_TYPE GEO_TYP2  \
# 0  Lower Super Output Areas and Data Zones   LSOADZ
# 1  Lower Super Output Areas and Data Zones   LSOADZ
# 2  Lower Super Output Areas and Data Zones   LSOADZ
# 3  Lower Super Output Areas and Data Zones   LSOADZ
# 4  Lower Super Output Areas and Data Zones   LSOADZ
#
#    Deprivation; classification of household [E][S][W] : Total\ Classification of household deprivation - Unit : Households  \
# 0                                                876
# 1                                                830
# 2                                                817
# 3                                                467
# 4                                                543
#
#    Deprivation; classification of household [E][S][W] : Household is not deprived in any dimension - Unit : Households  \
# 0                                                488
# 1                                                490
# 2                                                235
# 3                                                107
# 4                                                198
#
#    Deprivation; classification of household [E][S][W] : Household is deprived in 1 dimension - Unit : Households  \
# 0                                                314
# 1                                                288
# 2                                                359
# 3                                                187
# 4                                                195
#
#    Deprivation; classification of household [E][S][W] : Household is deprived in 2 dimensions - Unit : Households  \
# 0                                                 61
# 1                                                 47
# 2                                                169
# 3                                                113
# 4                                                113
#
#    Deprivation; classification of household [E][S][W] : Household is deprived in 3 dimensions - Unit : Households  \
# 0                                                 12
# 1                                                  4
# 2                                                 47
# 3                                                 51
# 4                                                 35
#
#    Deprivation; classification of household [E][S][W] : Household is deprived in 4 dimensions - Unit : Households
# 0                                                  1
# 1                                                  1
# 2                                                  7
# 3                                                  9
# 4                                                  2

# %%
dep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41729 entries, 0 to 41728
# Data columns (total 10 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   GEO_CODE                                                                                                                 41729 non-null  object
#  1   GEO_LABEL                                                                                                                41729 non-null  object
#  2   GEO_TYPE                                                                                                                 41729 non-null  object
#  3   GEO_TYP2                                                                                                                 41729 non-null  object
#  4   Deprivation; classification of household [E][S][W] : Total\ Classification of household deprivation - Unit : Households  41729 non-null  int64
#  5   Deprivation; classification of household [E][S][W] : Household is not deprived in any dimension - Unit : Households      41729 non-null  int64
#  6   Deprivation; classification of household [E][S][W] : Household is deprived in 1 dimension - Unit : Households            41729 non-null  int64
#  7   Deprivation; classification of household [E][S][W] : Household is deprived in 2 dimensions - Unit : Households           41729 non-null  int64
#  8   Deprivation; classification of household [E][S][W] : Household is deprived in 3 dimensions - Unit : Households           41729 non-null  int64
#  9   Deprivation; classification of household [E][S][W] : Household is deprived in 4 dimensions - Unit : Households           41729 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 3.2+ MB

# %% [markdown]
# # Demographic

# %%
# Read the file from github repo URL
url = "https://raw.githubusercontent.com/ListianingrumR/cusp_london_data_dive_2023/main/data/Green%20Space%20Consolidated%20Data%20-%20England%20-%20Version%202.1.csv"
demo_df= pd.read_csv(url, sep=";")

demo_df.head(5)
# Out:
#    Unnamed: 0  LSOA_Code                  LSOA_Name  MSOA_Code  \
# 0           1  E01000001        City of London 001A  E02000001
# 1           2  E01000002        City of London 001B  E02000001
# 2           3  E01000003        City of London 001C  E02000001
# 3           4  E01000005        City of London 001E  E02000001
# 4           5  E01000006  Barking and Dagenham 016A  E02000017
#
#                   MSOA_Name MSOA_Name_House_Of_Commons    LA_Code  \
# 0        City of London 001             City of London  E09000001
# 1        City of London 001             City of London  E09000001
# 2        City of London 001             City of London  E09000001
# 3        City of London 001             City of London  E09000001
# 4  Barking and Dagenham 016               Barking East  E09000002
#
#                 LA_Name LA_Name_For_Readability         Area  ...  \
# 0        City of London          City of London  133325.8873  ...
# 1        City of London          City of London  226199.3767  ...
# 2        City of London          City of London   57305.1083  ...
# 3        City of London          City of London  190745.2936  ...
# 4  Barking and Dagenham    Barking and Dagenham  144196.9391  ...
#
#    Unbuffrd_GOSpace_Area  Buffrd_GOSpace_Area  Unbuffered_GOSpace_Per_Capita  \
# 0                    0.0             0.000000                            0.0
# 1                    0.0         80106.351600                            0.0
# 2                    0.0          1857.634803                            0.0
# 3                    0.0             0.000000                            0.0
# 4                    0.0         27146.717850                            0.0
#
#       Pop_Area  PopArea_With_GOSpace_Access  Pcnt_PopArea_With_GOSpace_Access  \
# 0  133325.8873                     0.000000                          0.000000
# 1  226199.3767                 80106.351600                         35.414046
# 2   57305.1083                  1857.634803                          3.241657
# 3  190745.2936                     0.000000                          0.000000
# 4  144196.9391                 27146.717850                         18.826140
#
#    Pcnt_Pop_Without_GOSpace_Access  Pop_Without_GOSpace_Access  GSDI_AvgArea  \
# 0                       100.000000                 1296.000000             1
# 1                        64.585954                  746.613627             1
# 2                        96.758343                 1306.237636             1
# 3                       100.000000                 1121.000000             1
# 4                        81.173860                 1655.946741             1
#
#    GSDI_Access
# 0            1
# 1            2
# 2            1
# 3            1
# 4            1
#
# [5 rows x 31 columns]

# %%
demo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32844 entries, 0 to 32843
# Data columns (total 31 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                32844 non-null  int64
#  1   LSOA_Code                                 32844 non-null  object
#  2   LSOA_Name                                 32844 non-null  object
#  3   MSOA_Code                                 32844 non-null  object
#  4   MSOA_Name                                 32844 non-null  object
#  5   MSOA_Name_House_Of_Commons                32844 non-null  object
#  6   LA_Code                                   32844 non-null  object
#  7   LA_Name                                   32844 non-null  object
#  8   LA_Name_For_Readability                   32844 non-null  object
#  9   Area                                      32844 non-null  float64
#  10  IMD_st_areasha                            32844 non-null  float64
#  11  Population_IMD                            32844 non-null  int64
#  12  Population_Density                        32844 non-null  float64
#  13  Total_Pop_From_Ethnicity_Data             32844 non-null  int64
#  14  White_Pop                                 32844 non-null  int64
#  15  Mixed_Multiple_Ethnic_Group_Pop           32844 non-null  int64
#  16  Asian_AsianBritish_Pop                    32844 non-null  int64
#  17  Black_African_Caribbean_BlackBritish_Pop  32844 non-null  int64
#  18  Other_Ethnic_Group_Pop                    32844 non-null  int64
#  19  BAME_Pop                                  32844 non-null  int64
#  20  Income_Decile                             32844 non-null  int64
#  21  Unbuffrd_GOSpace_Area                     32844 non-null  float64
#  22  Buffrd_GOSpace_Area                       32844 non-null  float64
#  23  Unbuffered_GOSpace_Per_Capita             32844 non-null  float64
#  24  Pop_Area                                  32844 non-null  float64
#  25  PopArea_With_GOSpace_Access               32844 non-null  float64
#  26  Pcnt_PopArea_With_GOSpace_Access          32844 non-null  float64
#  27  Pcnt_Pop_Without_GOSpace_Access           32844 non-null  float64
#  28  Pop_Without_GOSpace_Access                32844 non-null  float64
#  29  GSDI_AvgArea                              32844 non-null  int64
#  30  GSDI_Access                               32844 non-null  int64
# dtypes: float64(11), int64(12), object(8)
# memory usage: 7.8+ MB
